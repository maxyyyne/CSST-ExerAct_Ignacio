# %% [markdown]
# # **ADVANCE MACHINE LEARNING**
#
# **Student's Name:** IGNACIO, Maxyne Nuela
#
# **Year & Section:** BS Computer Science - IS - 3B
#
# **Date:** February 28, 2024

# %% [markdown]
# **1. Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# **2. Data Loading**

# %%
df = pd.read_csv('Lesson_4_student_grades_dataset.csv')

# %% [markdown]
# **3. Initial Data Analysis**

# %%
stats = df.describe()
print(stats)

print(df.columns)
# Out:
#        Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# count     1000.000000            1000.000000           1000.000000
# mean         5.412309              85.210519             75.120286
# std          2.629236               8.765697             14.533710
# min          1.041688              70.096548             50.000582
# 25%          3.123759              77.232228             63.067549
# 50%          5.471266              85.562017             75.030696
# 75%          7.698876              92.813952             87.955176
# max          9.997459              99.982412             99.891043
#
#        Extracurricular_Activities  Travel_Time_to_School       Grades
# count                 1000.000000            1000.000000  1000.000000
# mean                     0.491000              34.256470    36.191615
# std                      0.500169              14.315794     7.096683
# min                      0.000000              10.001536    15.766457
# ...

# %% [markdown]
# **4. Converting into a Data Frame**

# %%
data = pd.DataFrame(X, columns=['Hours_of_Study', 'Attendance_Percentage', 'Grades'])
data['Grades']= Y

data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8e86d9ec0f67> in <cell line: 1>()
# ----> 1 data = pd.DataFrame(X, columns=['Hours_of_Study', 'Attendance_Percentage', 'Grades'])
#       2 data['Grades']= Y
#       3
#       4 data.head()
#
# NameError: name 'X' is not defined

# %% [markdown]
# **5. Initializing the Model**

# %%
model  = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f526595d08c3> in <cell line: 1>()
# ----> 1 model.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# **6. Making Predictions**

# %% [markdown]
# **7. Calculating the Mean Squarred Error**

# %% [markdown]
# **8. Predicting the Grade as per Attendance**
